# %% [markdown]
# ## 测试一些东西

# %%
# %matplotlib inline
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 查看 nii 切片图像

# %%
path = "anat/T1/T1.nii"
nii = nib.load(path).get_data()
img = nii[:, 128, :]
plt.imshow(img)
plt.show()

# %% [markdown]
# ## 查看 fft2 结果的类型

# %%
path = "anat/T1/T1.nii"
nii = nib.load(path).get_data()
img = nii[:, 128, :]
print(type(np.fft.fft2(img)))
# Out:
# <class 'numpy.ndarray'>
